# %%
from mix_log_parser import MixLogParser
folder = "/home/charles/Dropbox/Phd Portugal/oxum/31/results/20170124-171536"
m = MixLogParser(folder)
print m.ts
# Out:
# 20170124-171536

# %%
# %matplotlib inline

from tpc_plot import single_plot

y = m.tpsV
x = m.get_x_axis(y)

single_plot(x,y,'Elapsed Time (seconds)','tpsV', m.ts)

# %%
y = m.all_transactions
x = m.get_x_axis(y)

single_plot(x,y,'Elapsed Time (seconds)','overall tps', m.ts)

# %%
from mix_log_parser import MixLogParser
from tpc_plot import *
folder = "/home/charles/Dropbox/Phd Portugal/oxum/31/results/20170124-171536"
m = MixLogParser(folder)
d = m.get_all_tx_dict()

multi_plot(d, "Elapsed Seconds", "Transactions", m.ts)
